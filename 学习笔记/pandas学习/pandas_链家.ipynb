# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.rcParams['font.sans-serif'] = ['StHeiti']
plt.rcParams['axes.unicode_minus'] = False

# %%
data = pd.read_csv('./资料/链家.csv')
data.head()
# Out:
#       区域      地址                            标题    户型   面积    价格         楼层  \
# 0   燕莎租房     新源街  亮马桥 新源街  精装两居 交通便利 看房方便 随时入住  2室1厅   50  5800   中楼层(共6层)
# 1   望京租房    澳洲康都        澳洲康都东向精致两居室...........  2室1厅   79  7800  中楼层(共28层)
# 2  广安门租房    远见名苑        远见名苑 东向两居室 独立小区环境 适合居家  2室1厅   86  8000  低楼层(共25层)
# 3  天通苑租房  天通苑北一区          北一区简装两居，采光好，视野美，出行方便  2室1厅  103  5300  低楼层(共13层)
# 4  团结湖租房   团结湖北口        团结湖北口近地铁高楼层朝南向精装修正规两居室  2室1厅   63  6400  高楼层(共16层)
#
#          建造时间  朝向        更新时间  看房人数                                 备注  \
# 0    1981年建板楼   南  2017.07.21    26                      随时看房 精装修 集中供暖
# 1  2005年建板塔结合   东  2017.07.23    33   距离14号线(东段)东湖渠站731米 随时看房 精装修 集中供暖
# 2    2006年建塔楼   东  2017.07.20    34         距离7号线达官营站684米 随时看房 精装修 自供暖
# 3    2004年建板楼  东南  2017.07.25    30        距离5号线天通苑站927米 随时看房 精装修 集中供暖
# 4    1982年建塔楼   南  2017.07.26    30        距离10号线团结湖站88米 随时看房 精装修 集中供暖
#
#                                               链接地址
# 0  https://bj.lianjia.com/zufang/101101803342.html
# 1  https://bj.lianjia.com/zufang/101101753126.html
# 2  https://bj.lianjia.com/zufang/101101756753.html
# 3  https://bj.lianjia.com/zufang/101101780034.html
# 4  https://bj.lianjia.com/zufang/101101781083.html

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2760 entries, 0 to 2759
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   区域      2760 non-null   object
#  1   地址      2760 non-null   object
#  2   标题      2760 non-null   object
#  3   户型      2760 non-null   object
#  4   面积      2760 non-null   int64
#  5   价格      2760 non-null   int64
#  6   楼层      2760 non-null   object
#  7   建造时间    2758 non-null   object
#  8   朝向      2760 non-null   object
#  9   更新时间    2760 non-null   object
#  10  看房人数    2760 non-null   int64
#  11  备注      2760 non-null   object
#  12  链接地址    2760 non-null   object
# dtypes: int64(3), object(10)
# memory usage: 280.4+ KB

# %%
data.columns
# Out:
# Index(['区域', '地址', '标题', '户型', '面积', '价格', '楼层', '建造时间', '朝向', '更新时间', '看房人数',
#        '备注', '链接地址'],
#       dtype='object')

# %%
data.columns = ['district', 'address', 'title', 'house_type', 'area', 'price', 'floor', 'build_time', 'direction', 'update_time', 'view_num', 'extra_info', 'link']

# %%
data.head()
# Out:
#   district address                         title house_type  area  price  \
# 0     燕莎租房     新源街  亮马桥 新源街  精装两居 交通便利 看房方便 随时入住       2室1厅    50   5800
# 1     望京租房    澳洲康都        澳洲康都东向精致两居室...........       2室1厅    79   7800
# 2    广安门租房    远见名苑        远见名苑 东向两居室 独立小区环境 适合居家       2室1厅    86   8000
# 3    天通苑租房  天通苑北一区          北一区简装两居，采光好，视野美，出行方便       2室1厅   103   5300
# 4    团结湖租房   团结湖北口        团结湖北口近地铁高楼层朝南向精装修正规两居室       2室1厅    63   6400
#
#        floor  build_time direction update_time  view_num  \
# 0   中楼层(共6层)    1981年建板楼         南  2017.07.21        26
# 1  中楼层(共28层)  2005年建板塔结合         东  2017.07.23        33
# 2  低楼层(共25层)    2006年建塔楼         东  2017.07.20        34
# 3  低楼层(共13层)    2004年建板楼        东南  2017.07.25        30
# 4  高楼层(共16层)    1982年建塔楼         南  2017.07.26        30
#
#                           extra_info  \
# 0                      随时看房 精装修 集中供暖
# 1   距离14号线(东段)东湖渠站731米 随时看房 精装修 集中供暖
# 2         距离7号线达官营站684米 随时看房 精装修 自供暖
# 3        距离5号线天通苑站927米 随时看房 精装修 集中供暖
# 4        距离10号线团结湖站88米 随时看房 精装修 集中供暖
#
#                                               link
# 0  https://bj.lianjia.com/zufang/101101803342.html
# 1  https://bj.lianjia.com/zufang/101101753126.html
# 2  https://bj.lianjia.com/zufang/101101756753.html
# 3  https://bj.lianjia.com/zufang/101101780034.html
# 4  https://bj.lianjia.com/zufang/101101781083.html

# %%
### 租金最低和最高的房子
data.loc[data['price'].argmax()]
data.loc[data['price'].argmin()]
# Out:
# district                                                  良乡租房
# address                                                 伟业嘉园西里
# title                                     半地下室 家电齐全 集中供暖 简单装修
# house_type                                                1室1厅
# area                                                        46
# price                                                     1300
# floor                                                 地下室(共5层)
# build_time                                              2005年建
# direction                                                    南
# update_time                                         2017.07.19
# view_num                                                    14
# extra_info                                           随时看房 集中供暖
# link           https://bj.lianjia.com/zufang/101101538484.html
# Name: 2527, dtype: object

# %%
### 最近新上的10套房源
data.sort_values(by='update_time', ascending=False).head(10)

idx = data.sort_values(by='update_time', ascending=True).index[:10]
data.loc[idx]
# Out:
#      district   address                      title house_type  area  price  \
# 2439     良乡租房  良乡中路24号院   国泰百货旁边正规三居室 诚心出租 有钥匙随时看房       3室1厅    68   2400
# 1683    甘露园租房       康家园             康家园 2室1厅 5000元       2室1厅    65   5000
# 1281    东直门租房      华普花园    东二环 东直门 华普花园 出租三居室 看房方便       3室1厅   171  20000
# 1029     草桥租房      恋日花都         恋日花都 南三环 封闭管理小区 开间       1室0厅    54   4400
# 872      朝青租房     天鹅湾北区    天鹅湾北区精致时尚loft  业主婚房诚意出租       1室1厅    46   9500
# 2030     朝青租房     天鹅湾北区          天鹅湾北区 3室2厅 23000元       3室2厅   123  23000
# 142     牡丹园租房      塔院小区     牡丹园西土城地铁北医三院塔院小区南北向两居室       2室1厅    56   7500
# 140     五棵松租房        六建            六建大两居，看房随时，有钥匙。       2室1厅    61   5500
# 31      天宁寺租房     白菜湾社区            精装修2居价钱可聊随时拎包入住       2室1厅    59   5100
# 2562    CBD租房    和乔丽致公寓  CBD白领公寓 和乔经典loft 一居室 拎包入住       1室1厅    61  12000
#
#           floor  build_time direction update_time  view_num  \
# 2439   高楼层(共6层)    1990年建板楼         南  2017.07.14         0
# 1683   中楼层(共6层)    1997年建板楼         南  2017.07.14        25
# 1281  中楼层(共22层)    2001年建塔楼         南  2017.07.14         3
# 1029  高楼层(共17层)    2006年建塔楼        东北  2017.07.14        27
# 872    中楼层(共8层)  2010年建板塔结合         西  2017.07.14        39
# 2030  高楼层(共18层)  2007年建板塔结合         西  2017.07.14        12
# 142    中楼层(共6层)    1988年建板楼       南 北  2017.07.14        42
# 140   低楼层(共16层)    1988年建塔楼       南 北  2017.07.14        54
# 31     中楼层(共6层)    1992年建板楼       南 北  2017.07.14        34
# 2562  中楼层(共16层)    2003年建塔楼         北  2017.07.14         9
#
#                          extra_info  \
# 2439            距离房山线良乡南关站939米 随时看房
# 1683                      随时看房 集中供暖
# 1281   距离2号线东四十条站323米 随时看房 精装修 集中供暖
# 1029    距离10号线草桥站460米 随时看房 精装修 集中供暖
# 872     距离6号线青年路站736米 随时看房 精装修 集中供暖
# 2030    距离6号线青年路站481米 随时看房 精装修 集中供暖
# 142    距离10号线西土城站841米 随时看房 精装修 集中供暖
# 140         距离1号线五棵松站110米 随时看房 集中供暖
# 31                    随时看房 精装修 集中供暖
# 2562    距离1号线大望路站703米 随时看房 精装修 集中供暖
#
#                                                  link
# 2439  https://bj.lianjia.com/zufang/101101799730.html
# 1683  https://bj.lianjia.com/zufang/101101575607.html
# 1281  https://bj.lianjia.com/zufang/101101812938.html
# 1029  https://bj.lianjia.com/zufang/101101678256.html
# 872   https://bj.lianjia.com/zufang/101101606488.html
# 2030  https://bj.lianjia.com/zufang/101101047834.html
# 142   https://bj.lianjia.com/zufang/101101667962.html
# 140   https://bj.lianjia.com/zufang/101101663107.html
# 31    https://bj.lianjia.com/zufang/101101749057.html
# 2562  https://bj.lianjia.com/zufang/101101520184.html

# %%
## 查看所有更新时间
data['ut'] = pd.to_datetime(data['update_time'], format='%Y.%m.%d')
ut = data['ut']
ut.unique()
ut.nunique()
# Out:
# 14

# %%
## 查看看房人数信息
data['view_num']
data['view_num'].sum()
data['view_num'].mean()
data['view_num'].median()
data[data['view_num'] >=80]
## data.drop_duplicates() 去重
data[data['view_num'] >=100]
# Out:
#      district address             title house_type  area  price      floor  \
# 989    右安门内租房     清芷园    清芷园 2室1厅 7800元       2室1厅    78   7800  低楼层(共18层)
# 1002   右安门内租房     清芷园    清芷园 2室1厅 7800元       2室1厅    78   7800  低楼层(共18层)
# 1670    双榆树租房   双榆树东里  双榆树东里 3室1厅 8300元       3室1厅    71   8300  中楼层(共16层)
#
#       build_time direction update_time  view_num                 extra_info  \
# 989   2000年建板塔结合        西北  2017.07.23       122    距离4号线陶然亭站798米 随时看房 集中供暖
# 1002  2000年建板塔结合        西北  2017.07.23       122    距离4号线陶然亭站798米 随时看房 集中供暖
# 1670    1990年建塔楼        西北  2017.07.23       102   距离4号线人民大学站818米 随时看房 集中供暖
#
#                                                  link         ut
# 989   https://bj.lianjia.com/zufang/101100523048.html 2017-07-23
# 1002  https://bj.lianjia.com/zufang/101100523048.html 2017-07-23
# 1670  https://bj.lianjia.com/zufang/101100265730.html 2017-07-23

# %%
### 不同看房人数的房源数量
data.groupby('view_num', as_index=False)['district'].count()
# Out:
#     view_num  district
# 0          0       152
# 1          1       149
# 2          2       143
# 3          3       129
# 4          4       147
# ..       ...       ...
# 69        82         1
# 70        84         1
# 71        86         1
# 72       102         1
# 73       122         2
#
# [74 rows x 2 columns]

# %%
## 房租价格分布
data['price'].describe()
pd.qcut(data['price'], q=5)
# Out:
# 0         (5500.0, 6700.0]
# 1         (6700.0, 9300.0]
# 2         (6700.0, 9300.0]
# 3         (4200.0, 5500.0]
# 4         (5500.0, 6700.0]
#                ...
# 2755    (9300.0, 210000.0]
# 2756    (9300.0, 210000.0]
# 2757      (6700.0, 9300.0]
# 2758    (9300.0, 210000.0]
# 2759      (5500.0, 6700.0]
# Name: price, Length: 2760, dtype: category
# Categories (5, interval[float64, right]): [(1299.999, 4200.0] < (4200.0, 5500.0] < (5500.0, 6700.0] < (6700.0, 9300.0] < (9300.0, 210000.0]]

# %%
## 看房人数最多的朝向
tdf = data.groupby('direction', as_index=False)['view_num'].sum()
tdf.columns = ['direction', 'view_num_sum']
tdf.loc[tdf['view_num_sum'].argmax()]
tdf.set_index('direction', inplace=True)
plt.figure()
tdf.plot.bar()
plt.xlabel('direction')
plt.tight_layout()
plt.show()

# %%
## 房型分布
tdf = data.groupby('house_type', as_index=False)['district'].count()
tdf.columns = ['house_type', 'count']
plt.figure()
tdf.plot.bar(x='house_type', y='count')
plt.show()

# %%
## 最受欢迎的房型
tdf = data.groupby('house_type', as_index=False)['view_num'].sum()
tdf.columns = ['house_type', 'view_num_sum']
tdf.loc[tdf['view_num_sum'].argmax()]

# data.groupby('house_type', as_index=False).agg({'view_num': 'sum'})
# Out:
# house_type       2室1厅
# view_num_sum    17589
# Name: 5, dtype: object

# %%
## 房子平均租房价格(元/平米)
tdf = data['price'] / data['area']
data['price_per_m2'] = tdf
data['price_per_m2'].mean()
tdf.mean()
# Out:
# np.float64(87.72268429900454)

# %%
## 热门小区 小区的房源最多
tdf = data.groupby(['address'], as_index=False)['view_num'].sum()
tdf.columns = ['address', 'view_num_sum']
tdf.loc[tdf['view_num_sum'].argmax()]
tdf.sort_values(by='view_num_sum', ascending=False).head(10)
# Out:
#       address  view_num_sum
# 951       清芷园           246
# 369      卡布其诺           245
# 938      润枫水尚           217
# 1149    芍药居北里           194
# 743       新康园           186
# 1288     远洋山水           184
# 342       华贸城           176
# 15    万国城MOMA           176
# 1460      龙华园           171
# 1182   荣丰2008           170

# %%
tdf = data[['address', 'area']].groupby(['address'], as_index=False).count()
tdf.columns = ['address', 'count']
tdf.nlargest(10, 'count')
# Out:
#      address  count
# 1288    远洋山水     19
# 938     润枫水尚     10
# 401     后现代城      9
# 481      大方居      9
# 516      天畅园      9
# 541     太阳公元      9
# 711      慧忠里      9
# 1149   芍药居北里      9
# 1313    金地仰山      9
# 159       乐城      8

# %%
data[data['address'] == '远洋山水']
# Out:
#      district address                        title house_type  area  price  \
# 53       鲁谷租房    远洋山水    改好的两室一厅 带一个地下车位 也可单租 看房随时       2室1厅    76   7000
# 191      鲁谷租房    远洋山水          远洋山水 北区 近地铁大三居 随时看房       3室1厅   137  11500
> 'DataFrame' method of pandas.core.frame.DataFrame instance
#     Return the first `n` rows ordered by `columns` in descending order.
#
#     Return the first `n` rows with the largest values in `columns`, in
#     descending order. The columns that are not specified are returned as
#     well, but not used for ordering.
#
#     This method is equivalent to
#     ``df.sort_values(columns, ascending=False).head(n)``, but more
#     performant.
#
#     Parameters
#     ----------
#     n : int
#         Number of rows to return.
#     columns : label or list of labels
#         Column label(s) to order by.
#     keep : {'first', 'last', 'all'}, default 'first'
#         Where there are duplicate values:
#
#         - ``first`` : prioritize the first occurrence(s)
#         - ``last`` : prioritize the last occurrence(s)
#         - ``all`` : keep all the ties of the smallest item even if it means
#           selecting more than ``n`` items.
#
#     Returns
#     -------
#     DataFrame
#         The first `n` rows ordered by the given columns in descending
#         order.
#
#     See Also
#     --------
#     DataFrame.nsmallest : Return the first `n` rows ordered by `columns` in
#         ascending order.
#     DataFrame.sort_values : Sort DataFrame by the values.
#     DataFrame.head : Return the first `n` rows without re-ordering.
#
#     Notes
#     -----
#     This function cannot be used with all column types. For example, when
#     specifying columns with `object` or `category` dtypes, ``TypeError`` is
#     raised.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({'population': [59000000, 65000000, 434000,
#     ...                                   434000, 434000, 337000, 11300,
#     ...                                   11300, 11300],
#     ...                    'GDP': [1937894, 2583560 , 12011, 4520, 12128,
#     ...                            17036, 182, 38, 311],
#     ...                    'alpha-2': ["IT", "FR", "MT", "MV", "BN",
#     ...                                "IS", "NR", "TV", "AI"]},
#     ...                   index=["Italy", "France", "Malta",
#     ...                          "Maldives", "Brunei", "Iceland",
#     ...                          "Nauru", "Tuvalu", "Anguilla"])
#     >>> df
#               population      GDP alpha-2
#     Italy       59000000  1937894      IT
#     France      65000000  2583560      FR
#     Malta         434000    12011      MT
#     Maldives      434000     4520      MV
#     Brunei        434000    12128      BN
#     Iceland       337000    17036      IS
#     Nauru          11300      182      NR
#     Tuvalu         11300       38      TV
#     Anguilla       11300      311      AI
#
#     In the following example, we will use ``nlargest`` to select the three
#     rows having the largest values in column "population".
#
#     >>> df.nlargest(3, 'population')
#             population      GDP alpha-2
#     France    65000000  2583560      FR
#     Italy     59000000  1937894      IT
#     Malta       434000    12011      MT
#
#     When using ``keep='last'``, ties are resolved in reverse order:
#
#     >>> df.nlargest(3, 'population', keep='last')
#             population      GDP alpha-2
#     France    65000000  2583560      FR
#     Italy     59000000  1937894      IT
#     Brunei      434000    12128      BN
#
#     When using ``keep='all'``, the number of element kept can go beyond ``n``
#     if there are duplicate values for the smallest element, all the
#     ties are kept:
#
#     >>> df.nlargest(3, 'population', keep='all')
#               population      GDP alpha-2
#     France      65000000  2583560      FR
#     Italy       59000000  1937894      IT
#     Malta         434000    12011      MT
#     Maldives      434000     4520      MV
#     Brunei        434000    12128      BN
#
#     However, ``nlargest`` does not keep ``n`` distinct largest elements:
#
#     >>> df.nlargest(5, 'population', keep='all')
#               population      GDP alpha-2
#     France      65000000  2583560      FR
#     Italy       59000000  1937894      IT
#     Malta         434000    12011      MT
#     Maldives      434000     4520      MV
#     Brunei        434000    12128      BN
#
#     To order by the largest values in column "population" and then "GDP",
#     we can specify multiple columns like in the next example.
#
#     >>> df.nlargest(3, ['population', 'GDP'])
#             population      GDP alpha-2
#     France    65000000  2583560      FR
#     Italy     59000000  1937894      IT
#     Brunei      434000    12128      BN
